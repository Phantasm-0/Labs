# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['seg_train', 'seg_pred', 'seg_test']

# %%
# !ls ../input
# Out:
# seg_pred  seg_test  seg_train

# %%
import torch
from torch import nn
from torchvision import datasets, models, transforms

# %%
import torch.utils.data as tdata

# %%
# !ls ../input/seg_train/seg_train/
# !ls ../input/seg_test/seg_test/
# Out:
# buildings  forest  glacier  mountain  sea  street
# buildings  forest  glacier  mountain  sea  street

# %%
data_path_format = '../input/seg_{0}/seg_{0}'

# %%
np.random.seed(5315)
torch.manual_seed(9784)

# %%
# channel_means = (0.4301, 0.4572, 0.4540)
# channel_stds = (0.2698, 0.2680, 0.2983)  # 0.485, 0.456, 0.406
channel_means = (0.485, 0.456, 0.406)
channel_stds = (0.229, 0.224, 0.225)

# %%
image_transforms = transforms.Compose([
    transforms.Resize((150,150)),
    transforms.ToTensor(),
    transforms.Normalize(channel_means, channel_stds)
])

# %%
image_datasets = dict(zip(('dev', 'test'), [datasets.ImageFolder(data_path_format.format(key),transform=image_transforms) for key in ['train', 'test']]))
print(image_datasets)
# Out:
# {'dev': Dataset ImageFolder
#     Number of datapoints: 14034
#     Root Location: ../input/seg_train/seg_train
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None, 'test': Dataset ImageFolder
#     Number of datapoints: 3000
#     Root Location: ../input/seg_test/seg_test
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None}

# %%
devset_indices = np.arange(len(image_datasets['dev']))
devset_labels = image_datasets['dev'].targets

# %%
from sklearn import model_selection

# %%
train_indices, val_indices, train_labels,  val_labels = model_selection.train_test_split(devset_indices, devset_labels, test_size=0.1, stratify=devset_labels)

# %%
print(len(val_indices))
# Out:
# 1404

# %%
image_datasets['train'] = tdata.Subset(image_datasets['dev'], train_indices)
image_datasets['validation'] = tdata.Subset(image_datasets['dev'], val_indices)

# %%
print(image_datasets)
# Out:
# {'dev': Dataset ImageFolder
#     Number of datapoints: 14034
#     Root Location: ../input/seg_train/seg_train
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None, 'test': Dataset ImageFolder
#     Number of datapoints: 3000
#     Root Location: ../input/seg_test/seg_test
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None, 'train': <torch.utils.data.dataset.Subset object at 0x7f0843b0efd0>, 'validation': <torch.utils.data.dataset.Subset object at 0x7f0843b0ef98>}

# %%
from IPython.display import display

# %%
image_dataloaders = {key: tdata.DataLoader(image_datasets[key], batch_size=16,shuffle=True) for key in  ['train', 'validation']}

# %%
image_dataloaders['test'] = tdata.DataLoader(image_datasets['test'], batch_size=32)

# %%
def imshow(inp, title=None, fig_size=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0)) # C x H x W  # H x W x C
    inp = channel_stds * inp + channel_means
    inp = np.clip(inp, 0, 1)
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot('111')
    ax.imshow(inp)
    if title is not None:
        ax.set_title(title)
    ax.set_aspect('equal')
    plt.pause(0.001)

# %%
imshow(image_datasets['train'][8555][0]) # 5946

# %%
cuda_device = torch.device('cuda')
cpu_device = torch.device('cpu')
device = cuda_device

# %%
import torch.nn as nn
import torch.nn as F

class MyModel(nn.Module):
    def normalization_layer(self, input_, output_, kernel):
            return nn.Sequential(torch.nn.Conv2d(input_, output_, kernel, padding=1), 
                                  nn.Tanh(), nn.BatchNorm2d(output_), nn.MaxPool2d(2,2))
    def linear_layer(self,input_,output_):
            return nn.Sequential(torch.nn.Linear(input_, output_),nn.ReLU(), nn.Dropout(p = 0.15))
    
    def __init__(self):
            #150
            super(MyModel, self).__init__()
            self.norm1 = self.normalization_layer(3,12,2)
            self.norm2 = self.normalization_layer(12,24,2)
            self.norm3 = self.normalization_layer(24,48,2)
            self.norm4 = self.normalization_layer(48,96,2)
            
            self.fc1 = self.linear_layer(96 * 10 * 10,300)
            self.fc2 = self.linear_layer(300, 150)
            self.fc3 = self.linear_layer(150 , 6)

                
    def forward(self, x):
            x = self.norm1(x)
            x = self.norm2(x)
            x = self.norm3(x)
            x = self.norm4(x)
            
            #print(x.size(1) , x.size(2) , x.size(3))
            
            x = x.view(x.size(0),x.size(1) * x.size(2) * x.size(3) )
            x = self.fc1(x)
            x = self.fc2(x)
            x = self.fc3(x)
            return x    
ptr = MyModel()
ptr = ptr.to(device)

# %%
class BestModel:
    def __init__(self, path, initial_criterion):
        self.path = path
        self.criterion = initial_criterion
        
    def update(self, model, optimizer, criterion):
        self.criterion = criterion
        torch.save({'model_state': model.state_dict(), 'optimizer_state': optimizer.state_dict(), 'criterion': criterion}, self.path)
        
    def load_model_data(self):
        return torch.load(self.path)
    
    def restore(self, model, optimizer):
        model_data = self.load_model_data()
        model.load_state_dict(model_data['model_state'])
        optimizer.load_state_dict(model_data['optimizer_state'])

# %%
def train_model(epochs, model, optimizer, criterion, loaders, device, best_model, n_prints=1):
    print_every = len(loaders['train']) // n_prints
    for epoch in range(epochs):
        model.train()
        running_train_loss = 0.0
        
        for iteration, (xx, yy) in enumerate(loaders['train']):
            optimizer.zero_grad()
            xx, yy = xx.to(device), yy.to(device)
            out = model(xx)
            loss = criterion(out, yy)
            running_train_loss += loss.item()
            loss.backward()
            optimizer.step()
            
            if(iteration % print_every == print_every - 1):
                running_train_loss /= print_every
                print(f"Epoch {epoch}, iteration {iteration} training_loss {running_train_loss}")
                running_train_loss = 0.0
            
        with torch.no_grad():
            model.eval()
            running_corrects = 0
            running_total = 0
            running_loss = 0.0
            for xx, yy in loaders['validation']:
                batch_size = xx.size(0)
                xx, yy = xx.to(device), yy.to(device)

                out = model(xx)
                
                loss = criterion(out, yy)
                running_loss += loss.item()
                
                predictions = out.argmax(1)
                running_corrects += (predictions == yy).sum().item()
                running_total += batch_size
            
            mean_val_loss = running_loss / len(loaders['validation'])
            accuracy = running_corrects / running_total
            
            if accuracy > best_model.criterion:
                best_model.update(model, optimizer, accuracy)
            
            print(f"Epoch {epoch}, val_loss {mean_val_loss}, accuracy = {accuracy}")
    best_model.restore(model, optimizer)

# %%
import time
start = time.time()

# %%
optimizer = torch.optim.Adam(ptr.parameters(), lr=0.0003)
criterion = nn.CrossEntropyLoss()
best_model = BestModel('resnet_data',0.0)
train_model(20, ptr, optimizer, criterion,image_dataloaders, device, best_model=best_model, n_prints=5)
# Out:
# Epoch 0, iteration 157 training_loss 1.2878899091406713
# Epoch 0, iteration 315 training_loss 1.0959000836444805
# Epoch 0, iteration 473 training_loss 1.0214781598954261
# Epoch 0, iteration 631 training_loss 1.0157499178489553
# Epoch 0, iteration 789 training_loss 0.9943243102936805
# Epoch 0, val_loss 0.7013127580285072, accuracy = 0.7578347578347578
# Epoch 1, iteration 157 training_loss 0.8926998537175262
# Epoch 1, iteration 315 training_loss 0.894767343809333
# Epoch 1, iteration 473 training_loss 0.8448389864797834
# Epoch 1, iteration 631 training_loss 0.8642309102453763
# Epoch 1, iteration 789 training_loss 0.8607855759843995
# Epoch 1, val_loss 0.6292924803089012, accuracy = 0.7898860398860399
# Epoch 2, iteration 157 training_loss 0.8057727387434319
# Epoch 2, iteration 315 training_loss 0.8350592965755281
# Epoch 2, iteration 473 training_loss 0.7902301647995091
# Epoch 2, iteration 631 training_loss 0.8153740816478487
# Epoch 2, iteration 789 training_loss 0.8542826606691638
# Epoch 2, val_loss 0.6102262156253512, accuracy = 0.8091168091168092
# Epoch 3, iteration 157 training_loss 0.7406524963016752
# Epoch 3, iteration 315 training_loss 0.7543908234072637
# Epoch 3, iteration 473 training_loss 0.77165884703775
# Epoch 3, iteration 631 training_loss 0.7457570644873607
# Epoch 3, iteration 789 training_loss 0.7651235383899906
# Epoch 3, val_loss 0.5273351625285365, accuracy = 0.8297720797720798
# Epoch 4, iteration 157 training_loss 0.7186605409730839
# Epoch 4, iteration 315 training_loss 0.6997407073084312
# Epoch 4, iteration 473 training_loss 0.7165754869391646
# Epoch 4, iteration 631 training_loss 0.7582333907485008
# Epoch 4, iteration 789 training_loss 0.717883404485787
# Epoch 4, val_loss 0.5753036197274923, accuracy = 0.8354700854700855
# Epoch 5, iteration 157 training_loss 0.7040422879442384
# Epoch 5, iteration 315 training_loss 0.7046525301058081
# Epoch 5, iteration 473 training_loss 0.6678483266430565
# Epoch 5, iteration 631 training_loss 0.7160016794370699
# Epoch 5, iteration 789 training_loss 0.7166780836974518
# Epoch 5, val_loss 0.6158936778930101, accuracy = 0.8076923076923077
# Epoch 6, iteration 157 training_loss 0.6193117912434325
# Epoch 6, iteration 315 training_loss 0.6244791008626358
# Epoch 6, iteration 473 training_loss 0.6717947902558725
# Epoch 6, iteration 631 training_loss 0.6401573390334467
# Epoch 6, iteration 789 training_loss 0.6235342373764967
# Epoch 6, val_loss 0.498559755357829, accuracy = 0.844017094017094
# Epoch 7, iteration 157 training_loss 0.6062844561153575
# Epoch 7, iteration 315 training_loss 0.5941512315427955
# Epoch 7, iteration 473 training_loss 0.585307331354935
# Epoch 7, iteration 631 training_loss 0.6317892084016076
# Epoch 7, iteration 789 training_loss 0.5837167541060266
# Epoch 7, val_loss 0.4906866823069074, accuracy = 0.8475783475783476
# Epoch 8, iteration 157 training_loss 0.5562285394230976
# Epoch 8, iteration 315 training_loss 0.5429503912035423
# Epoch 8, iteration 473 training_loss 0.5917741909057279
# Epoch 8, iteration 631 training_loss 0.5744776437176934
# Epoch 8, iteration 789 training_loss 0.5484707897788361
# Epoch 8, val_loss 0.5318913422524929, accuracy = 0.8497150997150997
# Epoch 9, iteration 157 training_loss 0.5423108067222034
# Epoch 9, iteration 315 training_loss 0.560711888101282
# Epoch 9, iteration 473 training_loss 0.5281540111556083
# Epoch 9, iteration 631 training_loss 0.5607845130600507
# Epoch 9, iteration 789 training_loss 0.5355980827272693
# Epoch 9, val_loss 0.5169769407842647, accuracy = 0.8490028490028491
# Epoch 10, iteration 157 training_loss 0.5087246058296554
# Epoch 10, iteration 315 training_loss 0.5043514141742187
# Epoch 10, iteration 473 training_loss 0.4621496777274186
# Epoch 10, iteration 631 training_loss 0.5379492416977882
# Epoch 10, iteration 789 training_loss 0.49884302937720393
# Epoch 10, val_loss 0.557803051292219, accuracy = 0.8433048433048433
# Epoch 11, iteration 157 training_loss 0.4987864395768582
# Epoch 11, iteration 315 training_loss 0.46421349949285956
# Epoch 11, iteration 473 training_loss 0.48352708493041086
# Epoch 11, iteration 631 training_loss 0.4610571865982647
# Epoch 11, iteration 789 training_loss 0.47298879383862774
# Epoch 11, val_loss 0.5245853733610023, accuracy = 0.8603988603988604
# Epoch 12, iteration 157 training_loss 0.4517154694075071
# Epoch 12, iteration 315 training_loss 0.4375012146332596
# Epoch 12, iteration 473 training_loss 0.47140593435379524
# Epoch 12, iteration 631 training_loss 0.4728114040026182
# Epoch 12, iteration 789 training_loss 0.4151453367328342
# Epoch 12, val_loss 0.6214891641654752, accuracy = 0.8497150997150997
# Epoch 13, iteration 157 training_loss 0.42031305448352535
# Epoch 13, iteration 315 training_loss 0.4418329189095316
# Epoch 13, iteration 473 training_loss 0.44000189713662186
# Epoch 13, iteration 631 training_loss 0.44345925984126106
# Epoch 13, iteration 789 training_loss 0.45593805239783436
# Epoch 13, val_loss 0.715598881921985, accuracy = 0.8048433048433048
# Epoch 14, iteration 157 training_loss 0.4182511433676074
# Epoch 14, iteration 315 training_loss 0.41560941406443147
# Epoch 14, iteration 473 training_loss 0.43043684242646907
# Epoch 14, iteration 631 training_loss 0.4384410822693306
# Epoch 14, iteration 789 training_loss 0.40075567298674886
# Epoch 14, val_loss 0.6426382333209569, accuracy = 0.8361823361823362
# Epoch 15, iteration 157 training_loss 0.3907677225202699
# Epoch 15, iteration 315 training_loss 0.41225985352751576
# Epoch 15, iteration 473 training_loss 0.3923691136738922
# Epoch 15, iteration 631 training_loss 0.419215726277119
# Epoch 15, iteration 789 training_loss 0.40579084844528873
# Epoch 15, val_loss 0.6294357482428578, accuracy = 0.8482905982905983
# Epoch 16, iteration 157 training_loss 0.4216144872900051
# Epoch 16, iteration 315 training_loss 0.40230535258409345
# Epoch 16, iteration 473 training_loss 0.38722712914400464
# Epoch 16, iteration 631 training_loss 0.4007276258891142
# Epoch 16, iteration 789 training_loss 0.3956197693095177
# Epoch 16, val_loss 0.5862273915924809, accuracy = 0.8447293447293447
# Epoch 17, iteration 157 training_loss 0.3962920359041117
# Epoch 17, iteration 315 training_loss 0.3640934607556349
# Epoch 17, iteration 473 training_loss 0.36280788533106634
# Epoch 17, iteration 631 training_loss 0.3826220928207983
# Epoch 17, iteration 789 training_loss 0.3856708945447131
# Epoch 17, val_loss 0.5985989445312456, accuracy = 0.8504273504273504
# Epoch 18, iteration 157 training_loss 0.36488721071730684
# Epoch 18, iteration 315 training_loss 0.37620362177302563
# Epoch 18, iteration 473 training_loss 0.37123012976555886
# Epoch 18, iteration 631 training_loss 0.3524082171954686
# Epoch 18, iteration 789 training_loss 0.38363775068634676
# Epoch 18, val_loss 0.6343012574044141, accuracy = 0.8596866096866097
# Epoch 19, iteration 157 training_loss 0.39601320646043064
# Epoch 19, iteration 315 training_loss 0.3621274002745182
# Epoch 19, iteration 473 training_loss 0.35778873055418836
# Epoch 19, iteration 631 training_loss 0.35343385252017007
# Epoch 19, iteration 789 training_loss 0.34199968810322917
# Epoch 19, val_loss 0.7148525655608285, accuracy = 0.8311965811965812

# %%
end = time.time()
print(end - start)
# Out:
# 621.9091422557831

# %%
from torchvision.utils import make_grid

# %%
xx, yy = next(iter(image_dataloaders['validation']))

# %%
ptr.eval()
out = ptr(xx.cuda())
preds = out.argmax(1)
predicted_classes = [image_datasets['dev'].classes[c] for c in preds]
actual_classes = [image_datasets['dev'].classes[c] for c in yy]
imshow(make_grid(xx, nrow=4), fig_size=(8,8))
print(predicted_classes)
print(actual_classes)
# Out:
# ['forest', 'mountain', 'forest', 'sea', 'sea', 'mountain', 'forest', 'sea', 'forest', 'mountain', 'glacier', 'forest', 'street', 'sea', 'sea', 'buildings']
# ['glacier', 'glacier', 'forest', 'sea', 'sea', 'mountain', 'forest', 'sea', 'forest', 'mountain', 'glacier', 'forest', 'street', 'sea', 'glacier', 'buildings']

# %%
all_preds = []
correct_preds = []
with torch.no_grad():
    ptr.eval()
    for xx, yy in image_dataloaders['test']:
        xx = xx.to(device)
        output = ptr(xx)
        all_preds.extend(output.argmax(1).tolist())
        correct_preds.extend(yy.tolist())

# %%
from sklearn import metrics

# %%
all_preds = np.asarray(all_preds)
correct_preds = np.asarray(correct_preds)

# %%
target_names = image_datasets['test'].classes
print(metrics.classification_report(correct_preds, all_preds,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.85      0.79      0.82       437
#       forest       0.91      0.97      0.94       474
#      glacier       0.84      0.78      0.81       553
#     mountain       0.79      0.82      0.80       525
#          sea       0.82      0.86      0.84       510
#       street       0.87      0.86      0.86       501
#
#    micro avg       0.84      0.84      0.84      3000
#    macro avg       0.85      0.85      0.85      3000
# weighted avg       0.84      0.84      0.84      3000

# %%
confusion_matrix = metrics.confusion_matrix(correct_preds, all_preds)
pd.DataFrame(confusion_matrix, index=target_names, columns=target_names)
# Out:
#            buildings  forest  glacier  mountain  sea  street
# buildings        344      10        4        16   12      51
# forest             2     459        2         5    1       5
# glacier            4       7      432        67   39       4
# mountain           4       6       52       428   34       1
# sea               16       3       24        21  440       6
# street            35      20        3         4    8     431

# %%
def grad(x,y):
    x = x.clone()
    y = y.clone()
    x.requires_grad_(True)
    f = 1 / (1 + torch.exp(torch.dot(x,y)))
    f.backward()
    return x.grad
x = torch.tensor([1.,5.,-3.,4.])
y = torch.tensor([-2.,-6.,4.,-5.])
grad(x,y)
# Out:
# tensor([ 3.2076e-28,  9.6229e-28, -6.4152e-28,  8.0191e-28])
